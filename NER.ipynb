# %%
import pandas as pd
data = pd.read_csv("ner2.csv")
data.head()
# Out:
#                                                 text  \
# 0  ‼️ #RedAlert has been issued in #Chennai in vi...
# 1  ‼️ #RedAlert has been issued in #Chennai in vi...
# 2  ‼️ #RedAlert has been issued in #Chennai in vi...
# 3  ‼️ #RedAlert has been issued in #Chennai in vi...
# 4  “It takes years to build up, it takes moments ...
#
#                                     PreprocessedText         Words    Tag
# 0  RedAlert has been issued in Chennai in view of...      RedAlert      O
# 1  RedAlert has been issued in Chennai in view of...        issued      O
# 2  RedAlert has been issued in Chennai in view of...       Chennai  B-geo
# 3  RedAlert has been issued in Chennai in view of...  GlobalCrisis      O
# 4  It takes years to build up it takes moments to...         years      O

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
data["PreprocessedText"] = LabelEncoder().fit_transform(data["PreprocessedText"] )
data.head(30)
# Out:
#                                                  text  PreprocessedText  \
# 0   ‼️ #RedAlert has been issued in #Chennai in vi...                55
# 1   ‼️ #RedAlert has been issued in #Chennai in vi...                55
# 2   ‼️ #RedAlert has been issued in #Chennai in vi...                55
# 3   ‼️ #RedAlert has been issued in #Chennai in vi...                55
# 4   “It takes years to build up, it takes moments ...                27
# 5   “It takes years to build up, it takes moments ...                27
# 6   “It takes years to build up, it takes moments ...                27
# 7   “It takes years to build up, it takes moments ...                27
# 8   “It takes years to build up, it takes moments ...                27
# 9   “It takes years to build up, it takes moments ...                27
# 10  “It takes years to build up, it takes moments ...                27
# 11  “It takes years to build up, it takes moments ...                27
# ...

# %%
data.rename(columns={"PreprocessedText":"sentence_id","Words":"words","Tag":"labels"}, inplace =True)

# %%
data["labels"] = data["labels"].str.upper()

# %%
X= data[["sentence_id","words"]]
Y =data["labels"]

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size =0.2)

# %%
#building up train data and test data
train_data = pd.DataFrame({"sentence_id":x_train["sentence_id"],"words":x_train["words"],"labels":y_train})
test_data = pd.DataFrame({"sentence_id":x_test["sentence_id"],"words":x_test["words"],"labels":y_test})

# %%
train_data
# Out:
#      sentence_id                words labels
# 39            91                State      O
# 194           36            The Hindu      O
# 280           63              HOLIDAY      O
# 268           73  Kovalambeach beach   B-GEO
# 178           30     Himachal Pradesh  B-GEO
# ..           ...                  ...    ...
# 4             27                years      O
# 198           35    ransomstandstill       O
# 64            78              Chennai  B-GEO
# 211           41               houses      O
# 216           43          kodambakkam  B-GEO
#
# [243 rows x 3 columns]

# %% [markdown]
# ## **Training**

# %%
from simpletransformers.ner import NERModel,NERArgs

# %%
label = data["labels"].unique().tolist()
label
# Out:
# ['O', 'B-GEO']

# %%
args = NERArgs()
args.num_train_epochs = 10
args.learning_rate = 1e-4
args.overwrite_output_dir =True
args.train_batch_size = 32
args.eval_batch_size = 32

# %%
model = NERModel('bert', 'bert-base-cased',labels=label,args =args,use_cuda=False)
# Out:
# Downloading:   0%|          | 0.00/416M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForTokenClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model.train_model(train_data,eval_data = test_data,acc=accuracy_score)
# Out:
# ...
# Running Epoch 9 of 10:   0%|          | 0/3 [00:00<?, ?it/s]
# (30, 0.1635442882271794)

# %%
result, model_outputs, preds_list = model.eval_model(test_data)
# Out:
# ...
# Running Evaluation:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
result
# Out:
# {'eval_loss': 1.2835959494113922,
#  'precision': 0.8064516129032258,
#  'recall': 0.8064516129032258,
#  'f1_score': 0.8064516129032258}

# %%
prediction, model_output = model.predict(["Heavy Rain in Mylapore, Velacherry and Chennai Central"])
# Out:
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
prediction
# Out:
# [[{'Heavy': 'O'},
#   {'Rain': 'O'},
#   {'in': 'O'},
#   {'Mylapore,': 'B-GEO'},
#   {'Velacherry': 'B-GEO'},
#   {'and': 'O'},
#   {'Chennai': 'B-GEO'},
#   {'Central': 'B-GEO'}]]

# %%
prediction, model_output = model.predict(["Heavy Rain made Chennai into Venice"])
# Out:
# ...
# Running Prediction:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
prediction
# Out:
# [[{'Heavy': 'O'},
#   {'Rain': 'O'},
#   {'made': 'O'},
#   {'Chennai': 'B-GEO'},
#   {'into': 'O'},
#   {'Venice': 'O'}]]
